# %% [markdown]
# # UCI Iris Dataset
#
# The classic UCI iris dataset. This is used to test classification algorithms. Dataset can be found here: https://archive.ics.uci.edu/ml/datasets/Iris
#
# We will be using sklearn to import the datasets
#
# Lets run it through the data science pipeline
#
# 1. Data Wrangling
# 2. Exploratory Data Analysis
# 3. Pre-processing
# 4. Modeling
#
# For the models we will use the following algorithms:
# - SVC (sklearn)
# - Naive Bayes (sklearn)
# - Gradient boosting: XGBoost and LightGBM
#
# We will use the following metrics:
# - confusion matrix (sklearn.metrics)
# - classification score (sklearn.metrics)

# %%
# Import the dataset
from sklearn.datasets import load_iris

# %%
import pandas as pd

# %%
X, y = load_iris(return_X_y = True, as_frame = True)
X
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
